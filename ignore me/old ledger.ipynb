# %%
import argparse
import sys
from typing import List, Dict, Union, Literal
from datetime import date, datetime

TransactionType = ["Income", "Expense"]
TransactionDict = Dict[str, Union[int, TransactionType, date, str, float]]
Ledger = List[TransactionDict]

class Transaction:

    def __init__(
        self,
        date: date, 
        type: TransactionType, 
        info: str, 
        amount: float, 
        category: str, 
    )

        self.id: int = id
        self.type: TransactionType = type
        self.date: date = date
        self.info: str = info
        self.amount: float = amount
        self.category: str = category

class Finance_Ledger:

    def __init__
